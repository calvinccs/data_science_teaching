# %% [markdown]
# # Teaching plan for data science
#
# ## Introduction
# * What is data science?
#     * Using data to generate insight which are using in business
#
# * Knowledge and skills required to learn data science
#     * Programming
#     * Statistics
#     * Business sense
#
# * Career as a Data Scientist
#     * Data Science / Developer - Build application
#     * Business Analytics
#     * Job area: e-commerce, fintech, etc.
#     * The Data Science Workflow
#
# * Professional development as a data scientist
#     * Resource and opportunity in continue learning
#     * Hackathon
#
# * Big data
#     * Using database technology
#     * Cloud computing
#
# * Git and Github
#     * Backup and track change in your code
#     * Collaboration with others
#
#
# ## Python programming
# * Set up python programming environment - Anacoda and Jupyter notebook
#     * Basic operation of using Jypter notebook
#         - Coding, editing and result output all in one
#         - Interactive coding environment
#         - Use markdown cell for detail discussion
#         - Create presentation and document
#
#     * Coding without notebook
#         - .py file
#         - notebook, text editor and IDE (Introduce Sublime text editor)
#
#     * Why data scientist use notebook (e.g. Jypyter, R notebook etc)?
#
# * Introduction to Python - basic programming technique
#     * Data type (string, boolean, float, list, dict etc.)
#     * Loops (for, while, with etc.)
#     * User define function
#     * Error and trouble shooting
#
# * Using libraries and packages
#     * Install libraries using pip and conda
#     * Numpy
#
# ## Import data to python
# * Flat file csv, text etc.
#     * Libraries: Pandas and pandas dataframe
# * Json format
#     * Dealing with dicts
# * Import data from databases
#     * SQL (database, make query etc.)
# * Import data from Application Programming Interface (API)
#     * Showing example of Facebook, Linkedin etc.
#
# ## Data wrangling
# * Data wrangling
#
# * Web scrapping: scrap data from website and  and extract useful information from it
#     * Libraries: Request, Beautifulsoup
#
# ## Time series analysis
# * Introduce method to analysis time series data, i.e. dealing with timestamp
#     * Libraries: Pandas, datetime
#
# ## Data visualisation
# * Introduce useful libraries to visualise data
#     * Libraries: Matplotlib, Seaborn, Plotly
#
# * Introduce some business analytics tools
#     * Microsoft Power BI
#     * Tableau
#     * Qlikview
#
# ## Exploratory Data Analysis
# * Combinating the skills of data import, cleaning and visualisation to provide useful insight
#
# * Group discussion & presentation
#
# ## Statistics test
# * A/B testing
# * Probability theory
#
#
# ## Statistical modelling
# * Linear Regression
# * Polynomial Regression
# * Logistic Regression
#
#
# ## Machine Learning
# * Classification
# * Supervised learning
# * Unsupervised learning
#
# ## Natural Language Processing
#
#
# ## Deep Learning
#
#
# ## Big Data: Hadoop, Sparks
#
#
# ## Cloud (AWS, Azure Google Cloud)
